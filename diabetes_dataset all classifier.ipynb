# %%
# All imported Libeary

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style
style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df=pd.read_csv('diabetes_dataset.csv')                      # Read data set
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# All type  classifier

# %%
from   sklearn.linear_model import LogisticRegression
from   sklearn.tree import DecisionTreeClassifier
from   sklearn.ensemble import RandomForestClassifier
from   sklearn.svm import SVC
from   sklearn.linear_model import SGDClassifier

from   xgboost import XGBClassifier
from   lightgbm import LGBMClassifier
from   sklearn.naive_bayes import GaussianNB
from   sklearn.neighbors import KNeighborsClassifier
from   imblearn.over_sampling import RandomOverSampler

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(df.corr(), annot= True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
plt.figure(figsize =(11,4))
plt.subplot(1,2,1)
sns.boxplot(x='Outcome', y='Pregnancies', data = df)
plt.subplot(1,2,2)
sns.barplot(x='Outcome', y='Pregnancies', data = df)
# Out:
# <Axes: xlabel='Outcome', ylabel='Pregnancies'>

# %%
plt.figure(figsize =(11,4))
plt.subplot(1,2,1)
sns.histplot(x='Outcome', data = df)
plt.subplot(1,2,2)
sns.barplot(x='Outcome', y='Pregnancies', data = df)
# Out:
# <Axes: xlabel='Outcome', ylabel='Pregnancies'>

# %%
plt.figure(figsize =(11,4))
plt.subplot(1,2,1)
sns.boxplot(x='Outcome', y='BloodPressure', data = df)
plt.subplot(1,2,2)
sns.barplot(x='Outcome', y='BloodPressure', data = df)
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %%
plt.figure(figsize =(11,4))
plt.subplot(1,2,1)
sns.boxplot(x='Outcome', y='SkinThickness', data = df)
plt.subplot(1,2,2)
sns.barplot(x='Outcome', y='SkinThickness', data = df)
# Out:
# <Axes: xlabel='Outcome', ylabel='SkinThickness'>

# %%
plt.figure(figsize =(11,4))
plt.subplot(1,2,1)
sns.boxplot(x='Outcome', y='Age', data = df)
plt.subplot(1,2,2)
sns.barplot(x='Outcome', y='Age', data = df)
# Out:
# <Axes: xlabel='Outcome', ylabel='Age'>

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X= df.iloc[:, : -1]      # Seperator dataset 
Y= df.iloc[:,-1]

# %%
print('Indepandent feature shape :', X.shape)
print('depandent feature shape :', Y.shape)
# Out:
# Indepandent feature shape : (768, 8)
# depandent feature shape : (768,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(X,Y, test_size= 0.25, random_state= 0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train_sc=scaler.transform(x_train)
x_test_sc=scaler.transform(x_test)

# %% [markdown]
# Logistic Resgression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train_sc,y_train)
# Out:
# LogisticRegression()

# %%
pred_train = lr.predict(x_train_sc)
pred_test  =lr.predict(x_test_sc)

# %%
from sklearn.metrics import accuracy_score
print('Train accuracy  :', accuracy_score(y_train,pred_train))
print('test accuracy   :', accuracy_score(y_test,pred_test))
# Out:
# Train accuracy  : 0.7604166666666666
# test accuracy   : 0.7760416666666666

# %% [markdown]
# Decision Tree Classifier

# %%
classifier=DecisionTreeClassifier()
classifier.fit(x_train_sc,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_train = classifier.predict(x_train_sc)
pred_test  =classifier.predict(x_test_sc)

# %%
print('Train accuracy  :', accuracy_score(y_train,pred_train))
print('test accuracy   :', accuracy_score(y_test,pred_test))
# Out:
# Train accuracy  : 1.0
# test accuracy   : 0.7135416666666666

# %%
classifier = DecisionTreeClassifier(criterion = 'gini')
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
x_train.shape
# Out:
# (576, 8)

# %%
pred_train = classifier.predict(x_train_sc)
pred_test  =classifier.predict(x_test_sc)

# %%
print('Train accuracy  :', accuracy_score(y_train,pred_train))
print('test accuracy   :', accuracy_score(y_test,pred_test))
# Out:
# Train accuracy  : 0.640625
# test accuracy   : 0.6770833333333334

# %%
classifier = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)
classifier.fit(x_train_sc, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
pred_train = classifier.predict(x_train_sc)
pred_test  =classifier.predict(x_test_sc)
print('Train accuracy  :', accuracy_score(y_train,pred_train))
print('test accuracy   :', accuracy_score(y_test,pred_test))
# Out:
# Train accuracy  : 0.7934027777777778
# test accuracy   : 0.7291666666666666

# %% [markdown]
# Random Forrest Classifrier

# %%
classifier=RandomForestClassifier()
classifier.fit(x_train_sc,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_train = classifier.predict(x_train_sc)
pred_test  =classifier.predict(x_test_sc)

# %%
print('Train accuracy  :', accuracy_score(y_train,pred_train))
print('test accuracy   :', accuracy_score(y_test,pred_test))
# Out:
# Train accuracy  : 1.0
# test accuracy   : 0.8020833333333334

# %%
rf=RandomForestClassifier(max_depth =40, random_state=0,n_estimators =10)

# %%
rf.fit(x_train_sc,y_train)
# Out:
# RandomForestClassifier(max_depth=40, n_estimators=10, random_state=0)

# %%
pred_train = rf.predict(x_train_sc)
pred_test  =rf.predict(x_test)

# %%
print('Train accuracy  :', accuracy_score(y_train,pred_train))
print('test accuracy   :', accuracy_score(y_test,pred_test))
# Out:
# Train accuracy  : 0.9861111111111112
# test accuracy   : 0.4479166666666667

# %% [markdown]
# LGBMClassifier

# %%
from lightgbm import LGBMClassifier
regressor = LGBMClassifier(n_estimators = 10)
regressor.fit(x_train, y_train)

print('Training set score : ', regressor.score(x_train, y_train))
print('Testing set score  : ', regressor.score(x_test, y_test))
# Out:
# [LightGBM] [Info] Number of positive: 206, number of negative: 370
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000922 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 637
# [LightGBM] [Info] Number of data points in the train set: 576, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.357639 -> initscore=-0.585627
# [LightGBM] [Info] Start training from score -0.585627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# XGBClassifier

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier(n_estimators = 50)
classifier.fit(x_train, y_train)

print('Training set score : ', regressor.score(x_train, y_train))
print('Testing set score  : ', regressor.score(x_test, y_test))
# Out:
# Training set score :  0.8263888888888888
# Testing set score  :  0.7760416666666666

# %%
clasifier=KNeighborsClassifier(n_neighbors=7)

# %%
clasifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
print('Training set score : ', clasifier.score(x_train, y_train))
print('Testing set score  : ', clasifier.score(x_test, y_test))
# Out:
# Training set score :  0.7795138888888888
# Testing set score  :  0.7604166666666666

# %%
# Gaussian kernal radial basis function

classifier= SVC(kernel ='rbf')

# training set in x,y
classifier.fit(x_train_sc,y_train)
# Out:
# SVC()

# %%
print('Training set score : ', classifier.score(x_train_sc, y_train))
print('Testing set score  : ', classifier.score(x_test_sc, y_test))
# Out:
# Training set score :  0.8003472222222222
# Testing set score  :  0.78125

# %%
# Sigmodi kernal
classifier=SVC(kernel='sigmoid')
# training set in x,y
classifier.fit(x_train_sc,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
pred_train = classifier.predict(x_train_sc)
pred_test  =classifier.predict(x_test_sc)

# %%
print('Train accuracy  :', accuracy_score(y_train,pred_train))
print('test accuracy   :', accuracy_score(y_test,pred_test))
# Out:
# Train accuracy  : 0.4097222222222222
# test accuracy   : 0.390625

# %%
print('Training set score : ', classifier.score(x_train_sc, y_train))
print('Testing set score  : ', classifier.score(x_test_sc, y_test))
# Out:
# Training set score :  0.4097222222222222
# Testing set score  :  0.390625

# %%
# polynomial Kernel
classifier=SVC(kernel= 'poly', degree= 3)
# training set in x,y
classifier.fit(x_train_sc,y_train)
# Out:
# SVC(kernel='poly')

# %%
print('Traning set score  :', classifier.score(x_train_sc, y_train))
print('Testing set score  : ', classifier.score(x_test_sc, y_test))
# Out:
# Traning set score  : 0.8072916666666666
# Testing set score  :  0.7604166666666666

# %%
clf = SGDClassifier(loss="log_loss", max_iter=5)

# %%
clf.fit(x_train_sc,y_train)
# Out:
# SGDClassifier(loss='log_loss', max_iter=5)

# %%
print('Traning set score  :', clf.score(x_train_sc, y_train))
print('Testing set score  : ', clf.score(x_test_sc, y_test))
# Out:
# Traning set score  : 0.7569444444444444
# Testing set score  :  0.78125

# %%
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=200)

# %%
clf.fit(x_train_sc,y_train)
# Out:
# SGDClassifier(max_iter=200)

# %%
print('Traning set score  :', clf.score(x_train_sc, y_train))
print('Testing set score  : ', clf.score(x_test_sc, y_test))
# Out:
# Traning set score  : 0.7690972222222222
# Testing set score  :  0.8020833333333334

# %%
#GaussianNB()
clf = GaussianNB()
clf.fit(x_train_sc,y_train)
# Out:
# GaussianNB()

# %%
print('Traning set score  :', clf.score(x_train_sc, y_train))
print('Testing set score  : ', clf.score(x_test_sc, y_test))
# Out:
# Traning set score  : 0.765625
# Testing set score  :  0.765625

# %%
classifier=RandomForestClassifier()

# %%
search_para= {
    'n_estimators'  : [5,10,15,20],
    'max_depth'     : [7,10,20,30],
    'max_features'  : [4,5,6]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = search_para,
                           scoring = ['r2'],
                           cv = 5,
                           refit = 'r2',
                           verbose = 3)

grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=5; r2: (test=-0.157) total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=5; r2: (test=-0.099) total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=5; r2: (test=-0.213) total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=5; r2: (test=-0.592) total time=   0.0s
# [CV 5/5] END max_depth=7, max_features=4, n_estimators=5; r2: (test=-0.023) total time=   0.0s
# [CV 1/5] END max_depth=7, max_features=4, n_estimators=10; r2: (test=-0.194) total time=   0.0s
# [CV 2/5] END max_depth=7, max_features=4, n_estimators=10; r2: (test=-0.061) total time=   0.0s
# [CV 3/5] END max_depth=7, max_features=4, n_estimators=10; r2: (test=0.015) total time=   0.0s
# [CV 4/5] END max_depth=7, max_features=4, n_estimators=10; r2: (test=-0.516) total time=   0.0s
# ...

# %%
grid_search.best_params_
# Out:
# {'max_depth': 30, 'max_features': 4, 'n_estimators': 20}

# %%
grid_search.best_score_
# Out:
# -0.05747245503343044

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
# create a model
model= Sequential()
model.add(Dense(10, activation='relu', input_dim =8))
model.add(Dense(8, activation='relu')) 
model.add(Dense(5, activation='relu')) 
model.add(Dense(1, activation='sigmoid') )
          
'''model= Sequential()
model.add(Dense(11,activation='relu',input_dim=11))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))'''
# Out:
# "model= Sequential()\nmodel.add(Dense(11,activation='relu',input_dim=11))\nmodel.add(Dense(10,activation='relu'))\nmodel.add(Dense(1,activation='sigmoid'))"

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 10)                90
#
#  dense_4 (Dense)             (None, 8)                 88
#
#  dense_5 (Dense)             (None, 5)                 45
#
#  dense_6 (Dense)             (None, 1)                 6
#
# ...
# Total params: 229 (916.00 Byte)
# Trainable params: 229 (916.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer= 'Adam', loss= 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(x_train_sc,y_train,epochs=300,validation_split=0.2)
# Out:
# Epoch 1/300
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4647 - accuracy: 0.7739 - val_loss: 0.4719 - val_accuracy: 0.7845
# Epoch 2/300
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4653 - accuracy: 0.7783 - val_loss: 0.4667 - val_accuracy: 0.7759
# Epoch 3/300
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4631 - accuracy: 0.7783 - val_loss: 0.4701 - val_accuracy: 0.7672
# Epoch 4/300
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4638 - accuracy: 0.7717 - val_loss: 0.4672 - val_accuracy: 0.7759
# Epoch 5/300
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4623 - accuracy: 0.7804 - val_loss: 0.4680 - val_accuracy: 0.7672
# Epoch 6/300
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4646 - accuracy: 0.7717 - val_loss: 0.4695 - val_accuracy: 0.7759
# Epoch 7/300
# ...

# %%
y_pred= model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 4ms/step
